# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3360.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7141.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4074.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6003.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/735.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6166.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5698.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4918.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4386.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/425.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/335.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3084.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5269.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5315.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6216.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1211.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5119.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3684.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2710.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1395.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5726.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/682.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2650.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7193.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4874.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2535.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6599.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4032.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4896.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1192.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1803.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4732.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3939.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2732.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6150.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/664.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1559.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6113.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5178.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3201.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1513.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6936.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3489.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/678.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5683.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6034.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3015.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4322.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7171.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3868.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4839.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4291.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2242.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/953.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1726.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1442.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6606.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5374.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/203.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1532.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/317.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2877.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6856.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3659.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5960.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6919.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5935.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6056.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3538.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4265.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2979.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3539.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4394.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5611.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6485.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/398.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4477.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/112.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1730.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3349.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1965.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2209.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5912.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4685.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2046.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2892.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5953.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4171.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1861.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6900.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5959.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5822.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7317.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/758.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3495.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2768.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/370.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3681.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3265.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4999.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5943.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3377.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/253.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3233.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6954.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4242.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6630.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3764.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4070.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3753.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5227.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2091.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3194.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6218.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2240.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/646.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/397.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3886.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1879.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2123.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4797.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2495.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7163.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/393.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2941.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5583.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5212.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4052.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6820.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2102.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1986.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6279.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/369.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6306.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6375.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1280.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3830.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5727.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3581.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2252.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3032.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7238.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6956.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6957.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1590.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2176.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5196.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6096.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4195.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1696.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3196.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3909.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5739.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4067.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3161.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1633.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1253.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4332.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/830.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/592.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2685.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5705.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5860.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6397.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3117.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1416.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1215.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4062.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6952.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5457.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4024.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5493.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6683.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4870.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/940.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6370.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/673.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2645.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7340.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4701.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4883.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7020.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/389.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6089.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3627.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5016.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2397.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6369.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/971.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5834.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3417.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1403.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/247.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4031.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/161.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1797.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3086.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4597.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1769.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1849.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1199.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2779.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7157.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5092.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/81.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/976.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3865.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1541.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6026.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1863.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5939.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3301.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1992.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5274.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3158.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1219.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1720.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1919.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/948.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6460.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5176.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5500.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5470.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4236.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/745.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2146.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1390.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4464.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6115.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3130.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4708.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5259.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5024.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6368.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2471.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5920.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1691.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2036.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3340.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1116.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4347.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5724.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3728.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3913.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6751.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/127.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1843.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3439.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6994.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7198.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1069.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2181.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3521.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5078.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2067.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5893.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4323.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4324.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5252.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3799.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3727.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5287.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6373.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7295.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6005.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3998.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7201.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3072.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2813.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4211.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5687.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5956.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3058.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6691.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2116.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5174.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1239.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5309.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6042.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3387.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5869.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1063.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4509.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4358.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5058.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/867.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1745.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6675.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5250.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/403.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3103.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6500.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/878.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5756.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5554.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3900.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5326.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2791.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2145.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5038.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/960.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5152.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6061.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/307.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5944.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5099.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3601.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5588.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7079.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1706.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5707.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5854.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6064.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5020.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4571.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5308.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1394.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1549.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4652.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6256.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5468.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6496.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5639.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6871.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3041.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6081.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4513.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/721.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2117.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2180.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6320.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4266.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5348.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5677.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/902.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1885.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5168.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2930.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5991.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7013.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4349.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2668.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6519.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5440.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6327.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4424.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7050.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/535.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5734.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5202.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2905.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4860.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3703.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4893.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5258.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/950.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1173.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6477.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2394.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7167.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4250.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1712.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4710.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7367.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3754.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3976.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4624.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7257.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1523.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2364.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6616.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5057.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/969.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/586.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1468.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1196.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4418.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6571.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4889.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2619.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1900.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2590.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/807.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3871.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4337.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2841.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1053.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4450.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6512.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5672.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6808.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4084.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3022.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/263.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6356.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2470.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5011.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1985.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2528.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5623.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/984.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1823.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1640.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6776.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7127.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4752.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6332.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2865.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3731.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/195.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4872.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3351.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4014.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2642.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2724.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3242.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4083.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4087.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4782.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4018.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5728.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/537.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6615.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/778.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2851.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/450.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/670.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1651.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4831.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3403.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5694.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1240.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3696.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5261.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3454.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1678.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2129.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/187.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4594.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4385.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5688.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2272.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1652.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3203.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1397.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5053.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6687.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1225.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5406.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2035.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5279.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/44.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1047.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5723.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1856.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6363.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1287.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3396.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3532.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4188.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5986.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6912.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3250.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1123.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2581.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/356.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/873.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1198.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3783.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2999.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2946.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1371.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2161.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3901.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1425.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2943.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2617.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6415.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2277.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3710.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/462.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3724.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3744.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/677.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5875.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7018.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1330.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6902.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7251.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3445.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2128.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5121.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5451.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2574.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5184.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3322.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7064.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7161.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3638.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3457.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6145.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/503.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6123.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7140.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4258.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3354.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6750.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1636.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4712.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/199.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6597.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5068.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4661.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5557.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/746.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7296.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6713.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/89.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/710.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2389.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2513.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3122.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1598.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1072.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/88.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/871.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4367.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2399.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/225.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1137.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3567.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6093.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5878.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3469.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4355.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4457.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3584.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7245.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6030.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4993.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3973.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4135.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3621.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2435.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4053.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3261.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3887.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3739.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5345.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5169.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4290.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3296.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6791.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/817.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5649.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2160.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7216.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4309.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/628.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2088.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5105.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/366.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4483.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6886.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2545.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5338.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6605.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3894.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3268.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2309.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5580.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7133.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1869.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3177.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4679.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2257.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6810.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1866.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3131.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6468.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7183.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/931.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5668.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/531.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1061.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5215.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3794.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4575.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3749.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4508.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3911.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7246.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6827.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2024.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/671.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6041.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1353.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5622.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/231.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2436.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2407.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1859.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2752.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2750.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3612.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3616.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5497.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5339.tif
# ...
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/756.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2511.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2800.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2083.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1758.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1830.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/371.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3087.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3241.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2951.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2967.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2556.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/137.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2680.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1666.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1485.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1019.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/47.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2538.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/875.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/244.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1970.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1393.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/526.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/860.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1868.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1661.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2571.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/237.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3205.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1596.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1030.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1125.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/34.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1506.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/624.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1602.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/116.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2756.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/72.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2063.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2570.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/730.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2366.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2246.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/617.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/131.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3025.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/264.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/750.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1896.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1325.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3110.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1755.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3002.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2701.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1119.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2672.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1343.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3106.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1163.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2085.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2041.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1746.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1980.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/901.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2956.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3223.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1967.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/958.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1627.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/185.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2492.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1915.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2656.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2588.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2502.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3014.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2465.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/296.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/799.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2808.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3238.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1891.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2843.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/319.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/574.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/189.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1665.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/542.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2664.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/283.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/17.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/856.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2649.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1066.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/144.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2304.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3143.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3081.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1034.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1213.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1045.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2784.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2032.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2108.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2863.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/487.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/654.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1130.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1833.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1876.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1402.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2580.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/982.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3211.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/238.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/294.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/812.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1584.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/832.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1776.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1150.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/516.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3178.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/763.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1214.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2335.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3060.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3180.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2816.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/736.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1679.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/440.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2506.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/97.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/876.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1466.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1005.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2912.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3098.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1836.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1222.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2927.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3018.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1114.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1041.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/523.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/402.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1946.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/383.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/343.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1145.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/48.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3109.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/102.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/517.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/177.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3206.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1095.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2228.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1256.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1317.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2068.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1205.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2706.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3118.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2384.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1553.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2269.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/3062.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1229.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2263.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/205.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2737.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2147.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/729.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1947.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/182.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1847.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1875.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/482.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/475.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2444.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/724.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1040.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1207.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1121.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/518.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2762.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2953.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2065.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1349.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1355.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2913.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1841.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1291.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2426.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/232.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/175.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/838.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2280.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2644.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/347.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1511.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2477.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2256.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/863.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/2130.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/1202.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soil/156.tif

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import cv2
import glob
# %matplotlib inline
plt.rcParams['figure.figsize'] = (19.0, 17.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print(os.listdir("../input"))
# Out:
# ['weed-detection-in-soybean-crops']

# %% [markdown]
# Data preprocessing

# %%
data_dir = r'/kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/'
classes = ['broadleaf', 'grass', 'soil', 'soybean'] 
num_file = 1100 
all_files = [] 
num_data =num_file*len(classes)
Y = np.zeros(num_data)


for i, cls in enumerate(classes):
    all_files += [f for f in glob.glob(data_dir+cls+'/*.tif')][:num_file]
    Y[i*num_file:(i+1)*num_file] = i # label all classes with int [0.. len(classes)]

    
# Image dimension
im_width = 200
im_height = 200 
im_channel = 3
dim = im_width * im_height * im_channel

X = np.ndarray(shape=(num_data, im_width, im_height, im_channel), dtype=np.float64)

for idx, file in enumerate(all_files):
    X[idx] = cv2.resize(cv2.imread(file), (im_width, im_height))

X_train = np.empty(shape=(4000,im_width, im_height, im_channel), dtype=np.float64)
X_val = np.empty(shape=(200,im_width, im_height, im_channel), dtype=np.float64)
X_test = np.empty(shape=(200,im_width, im_height, im_channel), dtype=np.float64)

y_train = np.empty(4000)
y_val = np.empty(200)
y_test = np.empty(200) 

for i, cls in enumerate(classes): 
    X_test[50*i:50*(i+1)] = X[np.where(Y == i)[0][:50]]
    X_val[50*i:50*(i+1)] = X[np.where(Y == i)[0][50:100]]
    X_train[1000*i:1000*(i+1)] = X[np.where(Y == i)[0][100:]]
    
    y_test[50*i:50*(i+1)] = i
    y_val[50*i:50*(i+1)] = i
    y_train[1000*i:1000*(i+1)] = i
    
del Y 
del X

# Extract features 
#Shuffle training index
train_idxs = np.random.permutation(X_train.shape[0])
y_train  = y_train[train_idxs].astype(int)
X_train = X_train[train_idxs]

X_train = np.reshape(X_train, (X_train.shape[0], -1)).astype('float64')
X_test = np.reshape(X_test, (X_test.shape[0], -1)).astype('float64')
X_val = np.reshape(X_val, (X_val.shape[0], -1)).astype('float64')

X_tiny = X_train[100:110].astype('float64')
y_tiny = y_train[100:110].astype(int)
num_dev = 500

X_dev = X_train[0:num_dev].astype('float64')
y_dev = y_train[0:num_dev].astype(int)
print("X_train shape", X_train.shape, "| y_train shape:", y_train.shape)
print("X_test shape", X_test.shape, "| y_test shape:", y_test.shape)
print("X_val shape", X_val.shape, "| y_val shape:", y_val.shape)
print("X_dev shape", X_dev.shape, "| y_dev shape:", y_dev.shape)
print("X_tiny shape", X_tiny.shape, "| y_tiny shape:", y_tiny.shape)

#Subtract out the mean image 
#first: compute the mean image
# mean_image = np.mean(X_train, axis=0) #axis=0. stack horizontally
mean_image = 128
#Second subtract the mean image from train and test data 
X_train -= mean_image
X_val -= mean_image 
X_test -= mean_image
X_dev -= mean_image
X_tiny -= mean_image

#Third append the bias dimension using linear algebra trick
#Not for net
# X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
# X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
# X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
# X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
# X_tiny = np.hstack([X_tiny, np.ones((X_tiny.shape[0], 1))])

print('=====STACK BIAS term=====')
print("X_train shape", X_train.shape)
print("X_test shape", X_test.shape)
print("X_val shape", X_val.shape)
print("X_dev shape", X_dev.shape)
print("X_tiny shape", X_tiny.shape)
# Out:
# X_train shape (4000, 120000) | y_train shape: (4000,)
# X_test shape (200, 120000) | y_test shape: (200,)
# X_val shape (200, 120000) | y_val shape: (200,)
# X_dev shape (500, 120000) | y_dev shape: (500,)
# X_tiny shape (10, 120000) | y_tiny shape: (10,)
# =====STACK BIAS term=====
# X_train shape (4000, 120000)
# X_test shape (200, 120000)
# X_val shape (200, 120000)
# X_dev shape (500, 120000)
# X_tiny shape (10, 120000)

# %%
# plot some broadleaf pictures
from matplotlib import pyplot
from matplotlib.image import imread
# define location of dataset

# plot first few images
for i in range(1,9):
   # define subplot
   pyplot.subplot(330 + 1 + i)
   # define filename
   filename = data_dir + 'grass/' + str(i) + '.tif'
   # load image pixels
   image = imread(filename)
   # plot raw pixel data
   pyplot.imshow(image)
    
# show the figure
pyplot.show()

# %%
# plot some broadleaf pictures
from matplotlib import pyplot
from matplotlib.image import imread
# define location of dataset

# plot first few images
for i in range(1,9):
   # define subplot
   pyplot.subplot(330 + 1 + i)
   # define filename
   filename = data_dir + 'soil/' + str(i) + '.tif'
   # load image pixels
   image = imread(filename)
   # plot raw pixel data
   pyplot.imshow(image)
    
# show the figure
pyplot.show()

# %%
# plot some broadleaf pictures
from matplotlib import pyplot
from matplotlib.image import imread
# define location of dataset

# plot first few images
for i in range(1,9):
   # define subplot
   pyplot.subplot(330 + 1 + i)
   # define filename
   filename = data_dir + 'broadleaf/' + str(i) + '.tif'
   # load image pixels
   image = imread(filename)
   # plot raw pixel data
   pyplot.imshow(image)
    
# show the figure
pyplot.show()

# %%
# plot some broadleaf pictures
from matplotlib import pyplot
from matplotlib.image import imread
# define location of dataset

# plot first few images
for i in range(1,9):
   # define subplot
   pyplot.subplot(330 + 1 + i)
   # define filename
   filename = data_dir + 'soybean/' + str(i) + '.tif'
   # load image pixels
   image = imread(filename)
   # plot raw pixel data
   pyplot.imshow(image)
    
# show the figure
pyplot.show()

# %%
import os

broadleaf = []
for i in os.listdir("../input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/"):
    if '(' not in i and '%' not in i:
        i = "/broadleaf" + i
        broadleaf.append(i)
        
soil = []
for i in os.listdir("../input/weed-detection-in-soybean-crops/dataset/dataset/soil/"):
    if '(' not in i and '%' not in i:
        i = "soil/" + i
        soil.append(i)

grass = []
for i in os.listdir("../input/weed-detection-in-soybean-crops/dataset/dataset/grass/"):
    if '(' not in i and '%' not in i:
        i = "grass/" + i
        grass.append(i)

soybean = []
for i in os.listdir("../input/weed-detection-in-soybean-crops/dataset/dataset/soybean/"):
    if '(' not in i and '%' not in i:
        i = "soybean/" + i
        soybean.append(i)

All = broadleaf+soil+grass+soybean

    
print('All', len(All))
# Out:
# All 15336

# %%
# Visualize some images 
# Make sure that everything when OK
classes = ['broadleaf', 'grass', 'soil', 'soybean']
n_class = len(classes)
samples_per_class = 4


for y, cls in enumerate(classes):
    idxes = np.flatnonzero(y == y_train)
    idxes = np.random.choice(idxes, samples_per_class, replace = False)
    for i, idx in enumerate(idxes):
        plt_idx = i * n_class + y + 1
        plt.subplot(samples_per_class,n_class, plt_idx)
        plt.imshow(X_train[idx].reshape(im_width, im_height, im_channel).astype('uint8'))
        if(i==0): plt.title(cls)

plt.show()

# %% [markdown]
# 2 Layer Neural net
# Stacked RELU activation function.

# %%
class TwoLayerNet():
    def __init__(self, input_size, hidden_size, output_size, std= 1e-4):
        '''
        std: weight initialization term
        W1: first layer weight, shape(D x H) 
        W2: second layer weight shape(H x C) 
        C: num_classes(output_size) , H: hidden_size, D: data_dim(input_size) 
        '''
        self.params = {}
        self.params['W1'] = std * np.random.randn(input_size, hidden_size)
        self.params['b1'] = np.zeros(hidden_size)
        self.params['W2'] = std * np.random.randn(hidden_size, output_size)
        self.params['b2'] = np.zeros(output_size)
        
    def loss(self, X, y = None, reg=0.0):
        '''
        reg: regularization strength
        X: ndarray shape(N x C). N: num of data 
        y: vector of training label
        '''
        #DEfine relu activation function 
        relu = lambda x:np.maximum(0,x)

        #unpack
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']
        N, D = X.shape

        #Forward prop
        layer1 = relu(X.dot(W1) + b1)  #(N,D) x (D,H) = (N,H)
        scores = layer1.dot(W2) + b2

        #if target is not given then jump out 
        if(y is None): 
            return scores

        #compute the loss 
        ##Normalization trick to prevent overflow when compute exp 
        scores -= scores.max()#stack vertically

        scores = np.exp(scores)
        scores_sumexp = np.sum(scores, axis=1)#stack vertically

        ##Nomalize all score 
        softmax = scores / scores_sumexp.reshape(N,1)  #Shape: (N, C)
        #total loss of all training. -log of all correct score
        loss =  (-1.0) * np.sum(np.log(softmax[range(N),y]))

        ##Normalize the loss and add regularization strength 
        loss /= N 
        loss += reg * np.sum(W1 * W1) 
        loss += reg * np.sum(W2 * W2) 

        #Backward pass on the net 
        grads = {}

        correct_class_scores = scores[range(N), y]
        softmax[range(N), y] = (-1.0) * (scores_sumexp - correct_class_scores)/scores_sumexp
        softmax /= N


        #Want to find dW2(dL/dW2)
        # Derivation: dL/dW2 = dL/dscore * dscore/dW2(chain rule)
        #dL/dscore = softmax since L(score) = softmax(variable)
        #dscore/dW2 = relu_(hidden layer output)
        grads['W2'] = layer1.T.dot(softmax)
        grads['b2'] = np.sum(softmax, axis=0)#stack horizontally
        grads['W2'] += reg * 2 * W2

        #dL/dW1 = dL/dscore * dscore/drelu(layler1) * drelu(layer1)/dW1 
        #dL/dW1 = dW1 = softmax * W2 * X 
        hidden = softmax.dot(W2.T)

        #derivative of a max gate
        #Intuition: in forward pass if neuron didn't fire that mean. the derivative of that neuron 
        # is 0. This might be bad since this will kill gradient. 
        hidden[layer1 == 0] = 0 

        grads['W1'] = X.T.dot(hidden) 
        grads['b1'] = np.sum(hidden, axis=0) #stack horizontally 
        grads['W1'] += reg * 2 * W1

        return loss, grads

    def train(self, X, y, X_val, y_val, 
              learning_rate =1e-3, learning_rate_decay=0.95, 
              reg=5e-6, num_iters=100, 
              batch_size=200, it_verbose = 1, verbose=False):
        '''
        Train using SGD 
        Input: 
            X: nd array shape(N x D) 
            y: vector of train label 
            X_val: nd array shape( n_VAL , D) Use as validation set after each epoch 
            y_val: vector of validation label 
        '''
        N, D = X.shape
        N_val = X_val.shape[0]
        iteration_per_epoch = max(N/batch_size, 1)
        
        loss_hist = []
        train_acc_hist = []
        val_acc_hist = []
        
        for it in range(num_iters):
            sampling = np.random.choice(np.arange(N), batch_size, replace=False) 
            X_batch = X[sampling]
            y_batch = y[sampling]
            
            #compute loss and gradients
            loss, grads = self.loss(X_batch, y=y_batch, reg=reg)
            loss_hist.append(loss) 
            
            #Update rule 
            self.params['W1'] += (-1.0) * learning_rate * grads['W1']
            self.params['b1'] += (-1.0) * learning_rate * grads['b1']
            self.params['W2'] += (-1.0) * learning_rate * grads['W2']
            self.params['b2'] += (-1.0) * learning_rate * grads['b2']
            
            if(verbose and it%it_verbose==0):
                print('iteration: %d / %d | Loss: %f' % (it, num_iters, loss)) 
            # Every epoch, check train and val accuracy and decay learning rate.
            if (it % iteration_per_epoch == 0):
                # Check accuracy
                train_acc = (self.predict(X_batch) == y_batch).mean()
                val_acc = (self.predict(X_val) == y_val).mean()
                train_acc_hist.append(train_acc)
                val_acc_hist.append(val_acc)

                # Decay learning rate
                learning_rate *= learning_rate_decay
        return {
            'loss_hist':loss_hist,
            'train_acc_hist':train_acc_hist,
            'val_acc_hist':val_acc_hist
        }

    def predict(self, X):
        """
        Use the trained weights of this two-layer network to predict labels for
        data points. For each data point we predict scores for each of the C
        classes, and assign each data point to the class with the highest score.

        Inputs:
        - X: A numpy array of shape (N, D) giving N D-dimensional data points to
        classify.

        Returns:
        - y_pred: A numpy array of shape (N,) giving predicted labels for each of
        the elements of X. For all i, y_pred[i] = c means that X[i] is predicted
        to have class c, where 0 <= c < C.
        """
        y_pred = None
        relu = lambda x:np.maximum(0,x)
        # Unpack variables from the params dictionary
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']

        #Forward propagation though the network 
        layer1 = relu(X.dot(W1) + b1)
        scores = layer1.dot(W2) + b2 #shape: (N x C)
        y_pred = np.argmax(scores, axis=1)

        return y_pred

# %%
input_size = im_width * im_height * im_channel
hidden_size = 200
output_size = n_class 
std = 1e-3 # size initialization parameter

net = TwoLayerNet(input_size, hidden_size,output_size,std )
stats = net.train(X_dev, y_dev, X_val, y_val, 
              learning_rate =1e-5, learning_rate_decay=0.95, 
              reg=0.0, num_iters=70, 
              batch_size=100, it_verbose = 10,verbose=True)
# Out:
# iteration: 0 / 70 | Loss: 1.414839
# iteration: 10 / 70 | Loss: 1.331556
# iteration: 20 / 70 | Loss: 1.307648
# iteration: 30 / 70 | Loss: 1.217669
# iteration: 40 / 70 | Loss: 1.187584
# iteration: 50 / 70 | Loss: 1.199483
# iteration: 60 / 70 | Loss: 1.093208

# %%
# plot loss history and train/ validation accuracies history
plt.rcParams['figure.figsize'] = (15.0, 15.0) # set default size of plots
plt.subplot(2,1,1) 
plt.plot(stats['loss_hist'])
plt.title('Loss History')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2,1,2)
plt.plot(stats['train_acc_hist'], label='train')
plt.plot(stats['val_acc_hist'], label='val')
plt.xlabel('Epoch')
plt.ylabel('Classfication Accuracies')
plt.legend()
plt.show()

# %%
print((net.predict(X_test) == y_test).mean())
# Out:
# 0.55

# %% [markdown]
# Hyperparameter search

# %%
best_net = None # store the best model into this 
best_val= -1 #highest validation accuracy


hidden_unit = [200]
learn_rates = [7.6e-5]
regularizations = [0.0]
iterations = [600]

result = {}
best_stats = None

input_size = im_height * im_width * im_channel # 
output_size = 4 #4 class
for hidden in hidden_unit: 
    for learn in learn_rates:
        for r in regularizations:
            for iter in iterations:
                tune_net = TwoLayerNet(input_size,
                                       hidden_size=hidden,
                                       output_size=output_size,std=1e-3)
                stats = tune_net.train(X_train, y_train, X_val, y_val, 
                              num_iters=iter, batch_size=200, 
                              learning_rate=learn,learning_rate_decay=0.94, 
                              reg=r,  it_verbose = 100,verbose=True)
                train_acc = stats['train_acc_hist'][-1]#get last value 
                val_acc = stats['val_acc_hist'][-1]
                result[(hidden, learn)] = (train_acc, val_acc)
                #print log
                print('hs:',hidden,'learn:',learn,'reg',r,'iter',iter,'train-acc:',train_acc,'val_acc',val_acc)
                if(val_acc > best_val):
                    best_val = val_acc
                    #create best net
                    best_stats = stats
                    best_net = tune_net
                del tune_net
                del stats

print("Accuracy on Test set", (best_net.predict(X_test) == y_test).mean())
# Out:
# iteration: 0 / 600 | Loss: 1.415392
# iteration: 100 / 600 | Loss: 0.641663
# iteration: 200 / 600 | Loss: 0.469459
# iteration: 300 / 600 | Loss: 0.506346
# iteration: 400 / 600 | Loss: 0.516735
# iteration: 500 / 600 | Loss: 0.446626
# hs: 200 learn: 7.6e-05 reg 0.0 iter 600 train-acc: 0.85 val_acc 0.705
# Accuracy on Test set 0.715

# %%
# plot loss history and train/ validation accuracies history
plt.rcParams['figure.figsize'] = (15.0, 15.0) # set default size of plots
plt.subplot(2,1,1) 
plt.plot(best_stats['loss_hist'])
plt.title('Loss History')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2,1,2)
plt.plot(best_stats['train_acc_hist'], label='train')
plt.plot(best_stats['val_acc_hist'], label='val')
plt.xlabel('Epoch')
plt.ylabel('Classfication Accuracies')
plt.legend()
plt.show()

# %% [markdown]
# Check prediction statistic of the model

# %%
plt.hist(best_net.predict(X_test))
# Out:
# (array([43.,  0.,  0., 47.,  0.,  0., 50.,  0.,  0., 60.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)
